# %% [markdown]
# # SCATTER PLOT

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])

plt.scatter(x, y, c=colors,marker="s",edgecolor=)

plt.show()

# %% [markdown]
# # BUBBLE PLOT

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.random.rand(40)
y=np.random.rand(40)
z=np.random.rand(40)
colors=np.random.rand(40)
plt.scatter(x,y,s=z*1000,c=colors,alpha=0.3)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')

plt.colorbar()

plt.show()

# %% [markdown]
# # BOX PLOT

# %%
import matplotlib.pyplot as plt
import pandas as pd
# create dataset
data=[10,20,30,40,50]
#create plot
plt.boxplot(data)
#show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.DataFrame(np.random.rand(10,5)*1000,columns=["A","B","C","D","E"])
df.plot.box()
#show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
data1=[150,250,450]
data2=[100,200,400]
data=[data1,data2]
plt.boxplot(data)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.DataFrame(np.random.rand(10,5)*1000,columns=["A","B","C","D","E"])
df.plot(kind="box")
plt.show()
